# %%
import random
from textblob import TextBlob

with open('gulliver.txt', 'r') as file:
    text = file.read()

blob = TextBlob(text)

nouns = []
verbs = []
adjectives = []

for word,pos in blob.tags:   
    if (pos == 'NN'):
        nouns.append(word)
    
    if (pos == 'VB'):
        verbs.append(word)
        
    if (pos == 'JJ'):
        adjectives.append(word)
    
for line in range(4):
    a1 = random.choice(adjectives)
    a2 = random.choice(adjectives)
    n1 = random.choice(nouns)
    n2 = random.choice(nouns)
    n3 = random.choice(nouns)
    vb = random.choice(verbs)
    print(n1 + " " + a1 + " " +  vb  + " " + a2  + " " + n3)
# Out:
# insufficiency external happen advantageous gesture
# river improbable take other brevity
# selling latter be certain owner
# fear refused. live sensible _struldbrugs_

# %%
adjectives
# Out:
# ['www.gutenberg.org',
#  'several',
#  'remote',
#  ']',
#  'English',
#  'UTF-8',
#  'in_',
#  '[',
#  'original',
#  'ancient',
#  'intimate',
#  's',
#  'weary',
#  'curious',
#  'small',
#  'native',
#  'good',
#  'several',
#  'following',
#  'plain',
#  'simple',
#  'only',
#  'little',
#  'circumstantial',
#  'true',
#  'several',
#  'worthy',
#  'young',
#  'common',
#  'large',
#  'innumerable',
#  'several',
#  'minute',
#  'little',
#  'dissatisfied',
#  'possible',
#  'general',
#  'own',
#  'answerable',
#  'whole',
#  'large',
#  'ready',
#  'further',
#  'first',
#  'ready',
#  'own',
#  'great',
#  'frequent',
#  'loose',
#  'uncorrect',
#  'young',
#  'pious',
#  'glorious',
#  'human',
#  'decent',
#  'false',
#  'majesty',
#  'chief',
#  'first',
#  'second',
#  'several',
#  'own',
#  'pleased',
#  'afraid',
#  'watchful',
#  'many',
#  'rational',
#  'monstrous',
#  'detestable',
#  'principal',
#  'much',
#  'proper',
#  'next',
#  'own',
#  'great',
#  'false',
#  'own',
#  'public',
#  'good',
#  'utterly',
#  'incapable',
#  'full',
#  'little',
#  'single',
#  'upright',
#  'modest',
#  'common',
#  'young',
#  'female',
#  'good',
#  'great',
#  'prose',
#  'own',
#  'own',
#  'other',
#  'deducible',
#  'sufficient',
#  'subject',
#  'capable',
#  'contrary',
#  'second',
#  'great',
#  'human',
#  'female',
#  'likewise',
#  'own',
#  'likewise',
#  'careless',
#  'several',
#  'true',
#  'true',
#  'original',
#  'second',
#  'judicious',
#  'candid',
#  'many',
#  'first',
#  'young',
#  'apt',
#  'new-fangled',
#  'insomuch',
#  'own',
#  'old',
#  'altered',
#  'new',
#  'able',
#  'intelligible',
#  'other',
#  'great',
#  'bold',
#  'mere',
#  'mine',
#  'own',
#  'presumptuous',
#  'many',
#  'united',
#  'whole',
#  'stable',
#  'miserable',
#  'degenerated',
#  'illustrious',
#  'able',
#  'utmost',
#  'infernal',
#  'souls',
#  'other',
#  'vexatious',
#  'last',
#  '_Yahoo_',
#  'few',
#  'own',
#  'unavoidable',
#  'absurd',
#  'such',
#  'visionary',
#  'first',
#  'small',
#  'third',
#  'fourteen',
#  'old',
#  'scanty',
#  'great',
#  'narrow',
#  'small',
#  'other',
#  'useful',
#  'other',
#  'other',
#  'forty',
#  'physic',
#  'useful',
#  'long',
#  'good',
#  'other',
#  'several',
#  'small',
#  'second',
#  'good',
#  'few',
#  'bad',
#  'many',
#  'several',
#  'modern',
#  'good',
#  'great',
#  'last',
#  'fortunate',
#  'weary',
#  'advantageous',
#  'sail',
#  'first',
#  'prosperous',
#  'proper',
#  'violent',
#  'dead',
#  'immoderate',
#  'weak',
#  'strong',
#  'clear',
#  'able',
#  'sudden',
#  'own',
#  'legs',
#  'able',
#  'small',
#  '’',
#  'weak',
#  'tired',
#  'short',
#  'soft',
#  'day-light',
#  'able',
#  'long',
#  'thick',
#  'same',
#  'several',
#  'hot',
#  'confused',
#  'little',
#  'alive',
#  'left',
#  'much',
#  'human',
#  'high',
#  'mean',
#  'same',
#  'first',
#  'utmost',
#  'loud',
#  'full',
#  'distinct',
#  '_Hekinah',
#  'same',
#  'several',
#  'great',
#  'loose',
#  'left',
#  'same',
#  'violent',
#  'excessive',
#  'little',
#  'left',
#  'able',
#  'second',
#  'great',
#  'shrill',
#  'aloud',
#  'hundred',
#  'left',
#  'many',
#  'many',
#  'left',
#  'loose',
#  'first',
#  'good',
#  'prudent',
#  'till',
#  'left',
#  'same',
#  'quiet',
#  'right',
#  'capable',
#  'long',
#  'principal',
#  'former',
#  'left',
#  'middle',
#  'other',
#  'middle',
#  'other',
#  'many',
#  'few',
#  'submissive',
#  'left',
#  'strong',
#  'strict',
#  'great',
#  'learnt',
#  'several',
#  'laden',
#  'full',
#  's',
#  'first',
#  'several',
#  'small',
#  'ingenious',
#  'great',
#  'small',
#  'delicious',
#  'second',
#  'same',
#  'several',
#  'first',
#  '_Hekinah',
#  'first',
#  'universal',
#  'first',
#  'submissive',
#  'much',
#  'diminutive',
#  'prodigious',
#  'high',
#  'imperial',
#  'small',
#  'right',
#  'close',
#  'ten',
#  'mile',
#  'few',
#  'other',
#  'own',
#  'other',
#  'enough',
#  'good',
#  'many',
#  'much',
#  'cheerful',
#  'general',
#  'frequent',
#  'great',
#  'left',
#  'able',
#  'great',
#  'such',
#  'pleasant',
#  'few',
#  'nourishing',
#  'sleepy',
#  'first',
#  'early',
#  'bold',
#  'dangerous',
#  'confident',
#  'like',
#  'prudent',
#  'generous',
#  'first',
#  'able',
#  'excellent',
#  'great',
#  'renowned',
#  'several',
#  'other',
#  'great',
#  'hundred',
#  'hundred',
#  'long',
#  'wide',
#  'twenty-two',
#  'principal',
#  'high',
#  'strong',
#  'many',
#  'many',
#  'profound',
#  'soporiferous',
#  'half',
#  'high',
#  'mile',
#  'ridiculous',
#  'young',
#  'sharp',
#  'good',
#  'left',
#  'nose',
#  'unperceived',
#  'long',
#  'hundred',
#  'ready',
#  'next',
#  'hundred',
#  'great',
#  'ancient',
#  'whole',
#  'unnatural',
#  'common',
#  'great',
#  'high',
#  'wide',
#  'small',
#  'left',
#  'large',
#  'left',
#  'six-and-thirty',
#  'other',
#  'great',
#  'twenty',
#  'high',
#  'many',
#  'principal',
#  'same',
#  'several',
#  'impossible',
#  'loose',
#  'left',
#  'long',
#  'full',
#  'several',
#  'mild',
#  'entertaining',
#  'enclosed',
#  'forty',
#  'square',
#  'many',
#  'high',
#  'left',
#  'painted',
#  'last',
#  'disburdened',
#  'great',
#  'uneasy',
#  'only',
#  'guilty',
#  'uncleanly',
#  'candid',
#  'constant',
#  'open',
#  'full',
#  'due',
#  'offensive',
#  'first',
#  'momentous',
#  'necessary',
#  'other',
#  'fresh',
#  'unused',
#  'excellent',
#  'great',
#  'prepared',
#  'former',
#  'good',
#  'young',
#  'many',
#  'enough',
#  'strong',
#  'Austrian',
#  'limbs',
#  'twenty-eight',
#  'old',
#  'great',
#  'victorious',
#  'parallel',
#  'many',
#  'plain',
#  'simple',
#  'light',
#  'loose',
#  'gold',
#  'shrill',
#  'clear',
#  'imperial',
#  'majesty',
#  'syllable',
#  'several',
#  'present',
#  'many',
#  'strong',
#  'rabble',
#  'impatient',
#  'left',
#  'proper',
#  'right',
#  'sixth',
#  'alive',
#  'poor',
#  'much',
#  'same',
#  'much',
#  'common',
#  'smooth',
#  'same',
#  'tolerable',
#  'inured',
#  'prodigious',
#  'rich',
#  'idle',
#  'curious',
#  'great',
#  'imperial',
#  'several',
#  'fifty',
#  'considerable',
#  'mean',
#  'frequent',
#  'particular',
#  'great',
#  'much',
#  'secret',
#  'many',
#  'expensive',
#  'poisoned',
#  'large',
#  'whole',
#  'several',
#  'great',
#  'above-mentioned',
#  'favourable',
#  'whole',
#  'imperial',
#  'forty',
#  'other',
#  'proportionable',
#  'other',
#  'due',
#  'own',
#  'great',
#  'own',
#  'hundred',
#  'great',
#  'first',
#  'first',
#  'pesso',
#  'good',
#  'certain',
#  'proper',
#  'several',
#  'dangerous',
#  'prodigious',
#  'person.',
#  'ready',
#  'good',
#  'them.',
#  'other',
#  'secret',
#  'little',
#  'silver',
#  'other',
#  'small',
#  'exact',
#  '“',
#  'right',
#  'great',
#  'man-mountain',
#  'great',
#  'large',
#  'foot-cloth',
#  'majesty',
#  'chief',
#  'huge',
#  'same',
#  'able',
#  'several',
#  'right',
#  'prodigious',
#  'white',
#  'thin',
#  'strong',
#  'black',
#  'large',
#  'long',
#  's',
#  'great',
#  'large',
#  'right',
#  'middle',
#  'hollow',
#  'strong',
#  'huge',
#  'strange',
#  'same',
#  'right',
#  'several',
#  'flat',
#  'white',
#  'red',
#  'different',
#  'white',
#  'large',
#  'heavy',
#  'black',
#  'upper',
#  'other',
#  'white',
#  'prodigious',
#  'dangerous',
#  'own',
#  'other',
#  'large',
#  'middle',
#  'right',
#  'great',
#  'wonderful',
#  'transparent',
#  'transparent',
#  'certain',
#  'strange',
#  'lucid',
#  'incessant',
#  'unknown',
#  'inclined',
#  'latter',
#  'net',
#  'large',
#  'same',
#  'several',
#  'massy',
#  'yellow',
#  'real',
#  'immense',
#  '“',
#  'majesty',
#  'prodigious',
#  'left',
#  'pouch',
#  'capable',
#  'majesty',
#  's',
#  'several',
#  'ponderous',
#  'strong',
#  'other',
#  'certain',
#  'black',
#  'great',
#  'exact',
#  'great',
#  'due',
#  'majesty',
#  'fourth',
#  'eighty-ninth',
#  'majesty',
#  'auspicious',
#  'gentle',
#  'several',
#  'mean',
#  'ready',
#  'mine',
#  'clear',
#  'magnanimous',
#  'daunted',
#  'next',
#  'pouch',
#  'special',
#  'afraid',
#  'dead',
#  'same',
#  'former',
#  'imperial',
#  'curious',
#  'pole',
#  'continual',
#  'acute',
#  'various',
#  'remote',
#  'large',
#  'pouch',
#  'majesty',
#  'private',
#  'mine',
#  'other',
#  'little',
#  'uncommon',
#  'certain',
#  'good',
#  'general',
#  'conceive',
#  'short',
#  'possible',
#  'favourable',
#  'apprehensive',
#  'last',
#  'hide-and-seek',
#  'good',
#  'several',
#  'white',
#  'little',
#  'great',
#  'high',
#  'noble',
#  'liberal',
#  'great',
#  'vacant',
#  'chief',
#  'straight',
#  'other',
#  'whole',
#  'several',
#  'common',
#  'principal',
#  'private',
#  'partial',
#  'second',
#  'great',
#  'much',
#  'fatal',
#  'great',
#  'first',
#  'particular',
#  'blue',
#  'other',
#  'red',
#  'third',
#  'green',
#  'peculiar',
#  'great',
#  'different',
#  'former',
#  'such',
#  'other',
#  'new',
#  'old',
#  'creep',
#  'several',
#  'advanced',
#  'first',
#  'other',
#  'blue-coloured',
#  'red',
#  'next',
#  'green',
#  'third',
#  'girt',
#  'few',
#  'great',
#  'daily',
#  'large',
#  'prodigious',
#  'good',
#  'extraordinary',
#  'several',
#  'high',
#  'ordinary',
#  'next',
#  'many',
#  'quadrangular',
#  'other',
#  'ready',
#  'proper',
#  'short',
#  'military',
#  'parallel',
#  'much',
#  'several',
#  'pleased',
#  'great',
#  'close',
#  'able',
#  'full',
#  'whole',
#  'good',
#  'ill',
#  'fiery',
#  'other',
#  'same',
#  'such',
#  'dangerous',
#  'great',
#  'black',
#  'shaped',
#  'wide',
#  's',
#  'high',
#  'living',
#  'several',
#  'other',
#  '’',
#  'flat',
#  'hollow',
#  'first',
#  'such',
#  'imperial',
#  'possible',
#  'next',
#  'good',
#  'long',
#  'English',
#  'smooth',
#  'singular',
#  'general',
#  'old',
#  'experienced',
#  'great',
#  'close',
#  'twenty-four',
#  'thousand',
#  'thousand',
#  'many',
#  'full',
#  'pleased',
#  'mortal',
#  'whole',
#  'sour',
#  'free',
#  'several',
#  'own',
#  'right',
#  'left',
#  'middle',
#  'right',
#  'right',
#  'curious',
#  'whole',
#  'able',
#  '“',
#  'mighty',
#  'comfortable',
#  'fruitful',
#  'dreadful',
#  'sublime',
#  'celestial',
#  'following',
#  'solemn',
#  'man-mountain',
#  'great',
#  'man-mountain',
#  'principal',
#  'high',
#  'loving',
#  'own',
#  'extraordinary',
#  'man-mountain',
#  'safe',
#  'imperial',
#  'man-mountain',
#  'certain',
#  'great',
#  'other',
#  'royal',
#  'man-mountain',
#  '’',
#  'exact',
#  'own',
#  'solemn',
#  'above',
#  'daily',
#  'free',
#  'royal',
#  'other',
#  'twelfth',
#  'ninety-first',
#  'great',
#  'honourable',
#  'high-admiral',
#  'unlocked',
#  'full',
#  'whole',
#  's',
#  'many',
#  'gracious',
#  'useful',
#  'last',
#  'much',
#  'necessary',
#  'exact',
#  'great',
#  'first',
#  'special',
#  'half',
#  'high',
#  'eleven',
#  'broad',
#  'strong',
#  'ten',
#  'great',
#  'western',
#  'principal',
#  'short',
#  'utmost',
#  'strict',
#  'own',
#  'populous',
#  'exact',
#  'hundred',
#  'great',
#  'wide',
#  'capable',
#  'hundred',
#  'great',
#  'high',
#  'twenty',
#  'majesty',
#  'wide',
#  'outward',
#  'forty',
#  'other',
#  'royal',
#  'desirous',
#  'difficult',
#  'great',
#  'eighteen',
#  'high',
#  'wide',
#  'outer',
#  'high',
#  'impossible',
#  'infinite',
#  'same',
#  'great',
#  'able',
#  'hundred',
#  'high',
#  'strong',
#  'second',
#  'other',
#  'first',
#  'second',
#  'wide',
#  'other',
#  'first',
#  'hooked',
#  'inmost',
#  'middle',
#  'open',
#  'splendid',
#  'young',
#  'several',
#  'imperial',
#  'pleased',
#  'further',
#  'ready',
#  'general',
#  'first',
#  'particular',
#  'peculiar',
#  'other',
#  'curious',
#  'useful',
#  'chief',
#  'present',
#  'such',
#  'principal',
#  'private',
#  'personal',
#  'many',
#  'good',
#  'present',
#  'violent',
#  'potent',
#  'first',
#  'high',
#  'low',
#  'high',
#  'agreeable',
#  'ancient',
#  'low',
#  'imperial',
#  'fourteenth',
#  'high',
#  'other',
#  'high',
#  'imperial',
#  'high',
#  'other',
#  'intestine',
#  'other',
#  'great',
#  'large',
#  'powerful',
#  'other',
#  'human',
#  'large',
#  'much',
#  'certain',
#  'hundred',
#  'short',
#  's',
#  'thousand',
#  'other',
#  'great',
#  'obstinate',
#  'six-and-thirty',
#  'following',
#  'primitive',
#  'present',
#  'majesty',
#  'great',
#  'civil',
#  'several',
#  'Many',
#  'large',
#  'long',
#  'whole',
#  'incapable',
#  'fundamental',
#  'great',
#  'fifty-fourth',
#  'mere',
#  'true',
#  'convenient',
#  'humble',
#  's',
#  'chief',
#  'Big-endian',
#  'much',
#  's',
#  'much',
#  'private',
#  'bloody',
#  'six-and-thirty',
#  'various',
#  'forty',
#  'thirty',
#  'numerous',
#  'imperial',
#  'great',
#  'you.',
#  'humble',
#  'ready',
#  'invaders.',
#  'extraordinary',
#  ...]
